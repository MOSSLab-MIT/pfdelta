# %%
import os
import json
import torch
from tqdm import tqdm
from classes_for_analysis import PFDeltaDataset, PowerBalanceLoss

# %%
problem_sample_path = "solved_sample_10.json" 
with open(problem_sample_path) as f:
    pm_case = json.load(f)

data = PFDeltaDataset.build_heterodata(None, pm_case, feasibility=True)
pbl_tensor, delta_P_abs, delta_Q_abs, Qnet, Qbus, shuntQ = PowerBalanceLoss()(data)

# %%
data["bus"].bus_voltages
# Out:
# tensor([[-1.9216,  1.0000],
#         [-1.9105,  0.9878],
#         [-1.8956,  0.9929],
#         [-1.8170,  1.0000],
#         [-1.8081,  1.0033],
#         [-1.8565,  1.0000],
#         [-1.8661,  0.9978],
#         [-1.7149,  1.0000],
#         [-1.6406,  1.0160],
#         [-1.5589,  1.0000],
#         [-1.8599,  0.9971],
#         [-1.8779,  1.0000],
#         [-1.8693,  0.9866],
#         [-1.8812,  0.9881],
#         [-1.7884,  1.0000],
#         [-1.8533,  0.9788],
#         [-1.7528,  1.0013],
#         [-1.7810,  1.0000],
#         [-1.7898,  1.0000],
#         [-1.8257,  0.9078],
#         [-1.8118,  0.8984],
#         [-1.7699,  0.8980],
#         [-1.5837,  0.9753],
#         [-1.4605,  1.0000],
#         [-1.5265,  1.0000],
#         [-1.4948,  1.0000],
#         [-1.7326,  1.0000],
#         [-1.7583,  0.9875],
#         [-1.7733,  0.9926],
#         [-1.6316,  0.9605],
#         [-1.7706,  1.0000],
#         [-1.7403,  1.0000],
#         [-1.7008,  0.9589],
# ...

# %%
delta_Q_abs
# Out:
# tensor([1.0133e-06, 3.8743e-07, 6.1095e-07, 8.4937e-06, 1.5795e-06, 1.1921e-07,
#         7.4506e-08, 1.4901e-06, 1.9073e-06, 9.5367e-07, 4.0531e-06, 4.7684e-06,
#         1.7658e-06, 6.8545e-07, 4.7684e-07, 1.4901e-06, 8.3447e-06, 4.7684e-07,
#         1.0729e-06, 2.5034e-06, 6.5565e-07, 1.0580e-06, 1.6689e-06, 2.5034e-06,
#         2.3842e-06, 3.2187e-06, 1.3113e-06, 1.7881e-07, 2.1905e-06, 1.9073e-06,
#         3.3975e-06, 0.0000e+00, 2.9802e-07, 1.5646e-06, 0.0000e+00, 9.5665e-06,
#         8.1956e-07, 3.3379e-06, 1.3411e-07, 2.3842e-07, 1.0431e-06, 3.5763e-07,
#         2.6822e-07, 6.5565e-07, 4.0978e-07, 8.1211e-07, 2.7567e-07, 8.1956e-07,
#         7.1526e-07, 7.5996e-07, 1.8803e-06, 1.1921e-07, 8.9407e-08, 3.5465e-06,
#         3.6061e-06, 5.4836e-06, 4.5449e-07, 9.5367e-07, 4.7684e-07, 1.7881e-07,
#         4.1425e-06, 6.5565e-07, 1.9073e-06, 1.9073e-06, 1.4305e-06, 3.5763e-06,
#         3.8743e-07, 1.5259e-05, 9.5367e-07, 2.3842e-06, 9.5367e-07, 3.5763e-07,
# ...

# %%
Qnet
# Out:
# tensor([ 4.5333e-01, -1.8609e-01, -2.4742e-01, -2.9145e-01,  0.0000e+00,
#          1.4804e-01, -1.5217e-01,  5.2476e-01,  0.0000e+00, -1.2089e+00,
#         -2.5650e-02,  1.1408e+00, -8.0415e-02, -7.6896e-02,  5.3474e-01,
#         -2.9107e-01, -3.1125e-01,  6.0932e-02,  1.0407e+00, -5.1825e-01,
#         -5.8255e-02, -2.1073e-01, -7.4400e-02,  1.1587e+00, -1.1337e+00,
#          1.1142e+00,  5.5627e-01, -1.7800e-01, -1.0395e-01,  0.0000e+00,
#          2.5547e-01,  7.3127e-01, -3.4140e-01,  1.2556e+00,  0.0000e+00,
#          2.7490e-01,  0.0000e+00,  0.0000e+00, -1.9595e-01,  9.6741e-01,
#         -3.3635e-01,  7.9682e-01, -1.5415e-01, -1.5002e-01, -1.3243e-01,
#          1.1197e+00, -1.1854e-01, -6.3878e-02,  3.5088e+00, -1.6435e-01,
#         -6.2499e-03, -2.7805e-01, -2.1293e-01,  4.2324e-01,  1.4024e-01,
#          7.3082e-01, -2.7810e-02,  0.0000e+00, -8.5115e-01, -3.5161e-01,
#         -7.4462e-02,  3.3350e-01,  0.0000e+00,  0.0000e+00,  6.7292e+00,
# ...

# %%
Qbus
# Out:
# tensor([ 4.5333e-01, -1.8609e-01, -2.4742e-01, -2.9146e-01, -4.0267e-01,
#          1.4804e-01, -1.5217e-01,  5.2476e-01,  1.9073e-06, -1.2089e+00,
#         -2.5654e-02,  1.1408e+00, -8.0416e-02, -7.6896e-02,  5.3474e-01,
#         -2.9107e-01, -3.1126e-01,  6.0932e-02,  1.0407e+00, -5.1825e-01,
#         -5.8254e-02, -2.1073e-01, -7.4399e-02,  1.1587e+00, -1.1337e+00,
#          1.1142e+00,  5.5627e-01, -1.7800e-01, -1.0395e-01, -1.9073e-06,
#          2.5547e-01,  7.3127e-01, -3.4140e-01,  1.3956e+00,  0.0000e+00,
#          2.7489e-01, -2.4673e-01, -3.3379e-06, -1.9595e-01,  9.6741e-01,
#         -3.3634e-01,  7.9682e-01, -1.5415e-01, -6.9207e-02, -4.6801e-02,
#          1.2197e+00, -1.1854e-01,  8.5582e-02,  3.5088e+00, -1.6435e-01,
#         -6.2480e-03, -2.7805e-01, -2.1293e-01,  4.2324e-01,  1.4025e-01,
#          7.3082e-01, -2.7810e-02, -9.5367e-07, -8.5115e-01, -3.5161e-01,
#         -7.4458e-02,  3.3350e-01, -1.9073e-06,  1.9073e-06,  6.7292e+00,
# ...

# %%
shuntQ
# Out:
# tensor([ 0.0000,  0.0000,  0.0000,  0.0000, -0.4027,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.1400,  0.0000,  0.0000, -0.2467,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0808,  0.0856,  0.1000,  0.0000,  0.1495,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.1200,  0.0000,  0.0000,  0.0000,  0.0000,  0.1952,  0.0000,
#          0.0000,  0.1706,  0.0861,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
# ...
